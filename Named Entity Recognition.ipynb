# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup

# %%
api_endpoint = "https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&api-key=putyourownKEY"
def hit_api(api_endpoint):
    response = requests.get(url)
    return response
response = hit_api(api_endpoint)

# %%
def get_urls_from_response(reponse):
    list_of_urls =[]
    print("response code: ",response.status_code)
    data = response.json()
    web = data['response']['docs']
    for i in range(len(web)):
        list_of_urls.append(web[i]["web_url"])
    return list_of_urls

# %%
url_list = get_urls_from_response(response)
print(len(url_list))
# Out:
# response code:  200
# 10

# %%
for link in url_list:
    res = requests.get(link)
    soup = BeautifulSoup(res.text,"html.parser")
    matches = soup.select("main#site-content articleBody#story section div.StoryBodyCompanionColumn > div > p")
    content = ""
    for match in matches:
        content+=match.get_text()+"\n"
print(len(content))
# Out:
# 0

# %%
url_list
# Out:
# ['https://www.nytimes.com/2020/02/21/us/politics/bernie-sanders-russia.html',
#  'https://www.nytimes.com/2020/02/21/us/politics/richard-grenell-dni.html',
#  'https://www.nytimes.com/2020/02/20/us/politics/russian-interference-trump-democrats.html',
#  'https://www.nytimes.com/2020/02/23/us/politics/justice-department-dc-prosecutors.html',
#  'https://www.nytimes.com/2020/02/20/us/politics/amy-berman-jackson-roger-stone.html',
#  'https://www.nytimes.com/2020/02/18/us/roger-stone-sentencing.html',
#  'https://www.nytimes.com/2020/02/15/us/politics/trump-barr-justice-department.html',
#  'https://www.nytimes.com/2020/02/14/us/politics/andrew-mccabe-william-barr-flynn.html',
#  'https://www.nytimes.com/2020/02/14/us/politics/michael-flynn-prosecutors-barr.html',
#  'https://www.nytimes.com/2020/02/11/us/politics/roger-stone-sentencing.html']

# %%
content = ""
for i in range(len(url_list)): 
    res = requests.get(url_list[i])
    soup = BeautifulSoup(res.text,"html.parser")
    # print(res.text)
    matches = soup.select("main#site-content article#story section div.StoryBodyCompanionColumn > div > p")
    for match in matches:
        content+=match.get_text()+"\n"
    print(len(content))
# Out:
# 7205
# 15054
# 26917
# 39597
# 46301
# 56823
# 67629
# 76136
# 80557
# 94029

# %%
content = content.replace("\n"," ")

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
#Apply spaCy NLP method
doc = nlp(content)
# print([(X.text, X.label_) for X in doc.ents])

# %%
#Cardinality of the entities
labels = [x.label_ for x in doc.ents]
Counter(labels)
# Out:
# Counter({'GPE': 246,
#          'NORP': 94,
#          'PERSON': 712,
#          'DATE': 215,
#          'ORG': 198,
#          'EVENT': 6,
#          'CARDINAL': 87,
#          'ORDINAL': 11,
#          'FAC': 2,
#          'WORK_OF_ART': 1,
#          'TIME': 20,
#          'LOC': 2,
#          'MONEY': 1})

# %%
#Most common words - top N
items = [x.text for x in doc.ents]
Counter(items).most_common(3)
# Out:
# [('Trump', 148), ('Barr', 82), ('Stone', 69)]

# %%
displacy.render(doc, jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     WASHINGTON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  —
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has been trying to intervene in the
# ...
